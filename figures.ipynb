# %% [markdown]
# Generate figures for different combinations of data

# %%
import numpy as np
import matplotlib.pyplot as plt

plot_range = np.arange(0, 30)

any_door_no_check_20_4 = np.loadtxt("outputs/any_door-no_check_20_4.csv")
any_door_no_check_40_8 = np.loadtxt("outputs/any_door-no_check_40_8.csv")
any_door_no_check_60_12 = np.loadtxt("outputs/any_door-no_check_60_12.csv")
any_door_no_check_80_16 = np.loadtxt("outputs/any_door-no_check_80_16.csv")


plt.hist(
    any_door_no_check_20_4,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="20/4/4",
)
plt.hist(
    any_door_no_check_40_8,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="40/8/8",
)
plt.hist(
    any_door_no_check_60_12,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="60/12/12",
)
plt.hist(
    any_door_no_check_80_16,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="80/16/16",
)

plt.title("Any door, no ticket check, different crowds")
plt.xlabel("Entry/exit time (s)")
plt.ylabel("Relative frequency")
plt.legend()
plt.show()

# %%
any_door_with_check_20_4 = np.loadtxt("outputs/any_door-with_check_20_4.csv")
any_door_with_check_40_8 = np.loadtxt("outputs/any_door-with_check_40_8.csv")
any_door_with_check_60_12 = np.loadtxt("outputs/any_door-with_check_60_12.csv")
any_door_with_check_80_16 = np.loadtxt("outputs/any_door-with_check_80_16.csv")


plt.hist(
    any_door_with_check_20_4,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="20/4/4",
)
plt.hist(
    any_door_with_check_40_8,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="40/8/8",
)
plt.hist(
    any_door_with_check_60_12,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="60/12/12",
)
plt.hist(
    any_door_with_check_80_16,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="80/16/16",
)

plt.title("Any door, with ticket check, different crowds")
plt.xlabel("Entry/exit time (s)")
plt.ylabel("Relative frequency")
plt.legend()
plt.show()

# %%
front_door_no_check_20_4 = np.loadtxt("outputs/front_door-no_check_20_4.csv")
front_door_no_check_40_8 = np.loadtxt("outputs/front_door-no_check_40_8.csv")
front_door_no_check_60_12 = np.loadtxt("outputs/front_door-no_check_60_12.csv")
front_door_no_check_80_16 = np.loadtxt("outputs/front_door-no_check_80_16.csv")


plt.hist(
    front_door_no_check_20_4,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="20/4/4",
)
plt.hist(
    front_door_no_check_40_8,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="40/8/8",
)
plt.hist(
    front_door_no_check_60_12,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="60/12/12",
)
plt.hist(
    front_door_no_check_80_16,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="80/16/16",
)

plt.title("Front door entry, no ticket check, different crowds")
plt.xlabel("Entry/exit time (s)")
plt.ylabel("Relative frequency")
plt.legend()
plt.show()

# %%
front_door_with_check_20_4 = np.loadtxt("outputs/front_door-with_check_20_4.csv")
front_door_with_check_40_8 = np.loadtxt("outputs/front_door-with_check_40_8.csv")
front_door_with_check_60_12 = np.loadtxt("outputs/front_door-with_check_60_12.csv")
front_door_with_check_80_16 = np.loadtxt("outputs/front_door-with_check_80_16.csv")


plt.hist(
    front_door_with_check_20_4,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="20/4/4",
)
plt.hist(
    front_door_with_check_40_8,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="40/8/8",
)
plt.hist(
    front_door_with_check_60_12,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="60/12/12",
)
plt.hist(
    front_door_with_check_80_16,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="80/16/16",
)

plt.title("Front door entry, with ticket check, different crowds")
plt.xlabel("Entry/exit time (s)")
plt.ylabel("Relative frequency")
plt.legend()
plt.show()

# %% [markdown]
# # Below, different rules for same crowds are compared

# %%
# 20/4/4
any_door_no_check = np.loadtxt("outputs/any_door-no_check_20_4.csv")
front_door_no_check = np.loadtxt("outputs/front_door-no_check_20_4.csv")
any_door_with_check = np.loadtxt("outputs/any_door-with_check_20_4.csv")
front_door_with_check = np.loadtxt("outputs/front_door-with_check_20_4.csv")


plt.hist(
    any_door_no_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Any door, no ticket check",
)
plt.hist(
    front_door_no_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Front door entry, no ticket check",
)
plt.hist(
    any_door_with_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Any door, with ticket check",
)
plt.hist(
    front_door_with_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Front door entry, with ticket check",
)

plt.title("20 passengers, 4 exiting, 4 entering")
plt.xlabel("Entry/exit time (s)")
plt.ylabel("Relative frequency")
plt.legend()
plt.show()

# %%
# 40/8/8
any_door_no_check = np.loadtxt("outputs/any_door-no_check_40_8.csv")
front_door_no_check = np.loadtxt("outputs/front_door-no_check_40_8.csv")
any_door_with_check = np.loadtxt("outputs/any_door-with_check_40_8.csv")
front_door_with_check = np.loadtxt("outputs/front_door-with_check_40_8.csv")


plt.hist(
    any_door_no_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Any door, no ticket check",
)
plt.hist(
    front_door_no_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Front door entry, no ticket check",
)
plt.hist(
    any_door_with_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Any door, with ticket check",
)
plt.hist(
    front_door_with_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Front door entry, with ticket check",
)

plt.title("40 passengers, 8 exiting, 8 entering")
plt.xlabel("Entry/exit time (s)")
plt.ylabel("Relative frequency")
plt.legend()
plt.show()

# %%
# 60/12/12
any_door_no_check = np.loadtxt("outputs/any_door-no_check_60_12.csv")
front_door_no_check = np.loadtxt("outputs/front_door-no_check_60_12.csv")
any_door_with_check = np.loadtxt("outputs/any_door-with_check_60_12.csv")
front_door_with_check = np.loadtxt("outputs/front_door-with_check_60_12.csv")


plt.hist(
    any_door_no_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Any door, no ticket check",
)
plt.hist(
    front_door_no_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Front door entry, no ticket check",
)
plt.hist(
    any_door_with_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Any door, with ticket check",
)
plt.hist(
    front_door_with_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Front door entry, with ticket check",
)

plt.title("60 passengers, 12 exiting, 12 entering")
plt.xlabel("Entry/exit time (s)")
plt.ylabel("Relative frequency")
plt.legend()
plt.show()

# %%
# 80/16/16
any_door_no_check = np.loadtxt("outputs/any_door-no_check_80_16.csv")
front_door_no_check = np.loadtxt("outputs/front_door-no_check_80_16.csv")
any_door_with_check = np.loadtxt("outputs/any_door-with_check_80_16.csv")
front_door_with_check = np.loadtxt("outputs/front_door-with_check_80_16.csv")


plt.hist(
    any_door_no_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Any door, no ticket check",
)
plt.hist(
    front_door_no_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Front door entry, no ticket check",
)
plt.hist(
    any_door_with_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Any door, with ticket check",
)
plt.hist(
    front_door_with_check,
    plot_range,
    density=True,
    lw=2,
    histtype="step",
    label="Front door entry, with ticket check",
)

plt.title("80 passengers, 16 exiting, 16 entering")
plt.xlabel("Entry/exit time (s)")
plt.ylabel("Relative frequency")
plt.legend()
plt.show()

# %% [markdown]
# ## Error plot of trends

# %%
# Any door no check
a = np.loadtxt("outputs/any_door-no_check_20_4.csv")
b = np.loadtxt("outputs/any_door-no_check_40_8.csv")
c = np.loadtxt("outputs/any_door-no_check_60_12.csv")
d = np.loadtxt("outputs/any_door-no_check_80_16.csv")

x = [4, 8, 12, 16]
y = [np.mean(a), np.mean(b), np.mean(c), np.mean(d)]
yerr = [np.std(a), np.std(b), np.std(c), np.std(d)]

plt.errorbar(x,y, yerr, fmt="o-")
plt.xlabel("# of entering/exiting passengers")
plt.ylabel("Enter/exit-time")
plt.title("Trend using any door, no ticket check")
plt.grid()
plt.show()

# %%
# Any door with check
a = np.loadtxt("outputs/any_door-with_check_20_4.csv")
b = np.loadtxt("outputs/any_door-with_check_40_8.csv")
c = np.loadtxt("outputs/any_door-with_check_60_12.csv")
d = np.loadtxt("outputs/any_door-with_check_80_16.csv")

x = [4, 8, 12, 16]
y = [np.mean(a), np.mean(b), np.mean(c), np.mean(d)]
yerr = [np.std(a), np.std(b), np.std(c), np.std(d)]

plt.errorbar(x,y, yerr, fmt="o-")
plt.xlabel("# of entering/exiting passengers")
plt.ylabel("Enter/exit-time")
plt.title("Trend using any door, with ticket check")
plt.grid()
plt.show()

# %%
# Front door no check
a = np.loadtxt("outputs/front_door-no_check_20_4.csv")
b = np.loadtxt("outputs/front_door-no_check_40_8.csv")
c = np.loadtxt("outputs/front_door-no_check_60_12.csv")
d = np.loadtxt("outputs/front_door-no_check_80_16.csv")

x = [4, 8, 12, 16]
y = [np.mean(a), np.mean(b), np.mean(c), np.mean(d)]
yerr = [np.std(a), np.std(b), np.std(c), np.std(d)]

plt.errorbar(x,y, yerr, fmt="o-")
plt.xlabel("# of entering/exiting passengers")
plt.ylabel("Enter/exit-time")
plt.title("Trend for front door entry, no ticket check")
plt.grid()
plt.show()

# %%
# Front door ticket check
a = np.loadtxt("outputs/front_door-with_check_20_4.csv")
b = np.loadtxt("outputs/front_door-with_check_40_8.csv")
c = np.loadtxt("outputs/front_door-with_check_60_12.csv")
d = np.loadtxt("outputs/front_door-with_check_80_16.csv")

x = [4, 8, 12, 16]
y = [np.mean(a), np.mean(b), np.mean(c), np.mean(d)]
yerr = [np.std(a), np.std(b), np.std(c), np.std(d)]

plt.errorbar(x,y, yerr, fmt="o-")
plt.xlabel("# of entering/exiting passengers")
plt.ylabel("Enter/exit-time")
plt.title("Trend for front door entry, with ticket check")
plt.grid()
plt.show()

# %% [markdown]
# # Compare rules for same passenger counts

# %%
# 20/4/4
a4 = np.loadtxt("outputs/any_door-no_check_20_4.csv")
b4= np.loadtxt("outputs/any_door-with_check_20_4.csv")
c4 = np.loadtxt("outputs/front_door-no_check_20_4.csv")
d4 = np.loadtxt("outputs/front_door-with_check_20_4.csv")

x = [4, 8, 12, 16]
y4 = [a4, b4, c4, d4]

plt.boxplot(y4, positions=x, widths=[2, 2, 2, 2])
plt.ylabel("Enter/exit-time")

plt.xticks(
    x,
    [
        "Any door\nNo check",
        "Any door\nWith check",
        "Front door\nNo check",
        "Front door\nWith check",
    ],
)

plt.ylim([0, 50])
plt.title("20 passengers, 4 exiting, 4 entering")
plt.grid()
plt.show()

# %%
# 40/8/8
a8 = np.loadtxt("outputs/any_door-no_check_40_8.csv")
b8 = np.loadtxt("outputs/any_door-with_check_40_8.csv")
c8 = np.loadtxt("outputs/front_door-no_check_40_8.csv")
d8 = np.loadtxt("outputs/front_door-with_check_40_8.csv")

x = [4, 8, 12, 16]
y8 = [a8, b8, c8, d8]

plt.boxplot(y8, positions=x, widths=[2, 2, 2, 2])
plt.ylabel("Enter/exit-time")

plt.xticks(
    x,
    [
        "Any door\nNo check",
        "Any door\nWith check",
        "Front door\nNo check",
        "Front door\nWith check",
    ],
)

plt.ylim([0, 50])
plt.title("40 passengers, 8 exiting, 8 entering")
plt.grid()
plt.show()

# %%
# 60/12/12
a12 = np.loadtxt("outputs/any_door-no_check_60_12.csv")
b12 = np.loadtxt("outputs/any_door-with_check_60_12.csv")
c12 = np.loadtxt("outputs/front_door-no_check_60_12.csv")
d12 = np.loadtxt("outputs/front_door-with_check_60_12.csv")

x = [4, 8, 12, 16]
y12 = [a12, b12, c12, d12]

plt.boxplot(y12, positions=x, widths=[2, 2, 2, 2])
plt.ylabel("Enter/exit-time")

plt.xticks(
    x,
    [
        "Any door\nNo check",
        "Any door\nWith check",
        "Front door\nNo check",
        "Front door\nWith check",
    ],
)

plt.ylim([0, 50])
plt.title("60 passengers, 12 exiting, 12 entering")
plt.grid()
plt.show()

# %%
# 80/16/16
a16 = np.loadtxt("outputs/any_door-no_check_80_16.csv")
b16 = np.loadtxt("outputs/any_door-with_check_80_16.csv")
c16 = np.loadtxt("outputs/front_door-no_check_80_16.csv")
d16 = np.loadtxt("outputs/front_door-with_check_80_16.csv")

x = [4, 8, 12, 16]
y16 = [a16, b16, c16, d16]

plt.boxplot(y16, positions=x, widths=[2, 2, 2, 2])
plt.ylabel("Enter/exit-time")

plt.xticks(
    x,
    [
        "Any door\nNo check",
        "Any door\nWith check",
        "Front door\nNo check",
        "Front door\nWith check",
    ],
)

plt.ylim([0, 50])
plt.title("80 passengers, 16 exiting, 16 entering")
plt.grid()
plt.show()

# %%
fig, axs = plt.subplots(2, 2)

ylim = [0, 50]

# 20/4/4
ax = axs[0][0]
ax.boxplot(y4, positions=x, widths=[2, 2, 2, 2])
ax.set_ylabel("Enter/exit-time")

ax.set_xticks(
    x,
    [
        "Any door\nNo check",
        "Any door\nWith check",
        "Front door\nNo check",
        "Front door\nWith check",
    ],
)

ax.set_ylim(ylim)
ax.set_title("a) 20 passengers, 4 exiting, 4 entering")
ax.grid()

# 40/8/8
ax = axs[0][1]
ax.boxplot(y8, positions=x, widths=[2, 2, 2, 2])
ax.set_ylabel("Enter/exit-time")

ax.set_xticks(
    x,
    [
        "Any door\nNo check",
        "Any door\nWith check",
        "Front door\nNo check",
        "Front door\nWith check",
    ],
)

ax.set_ylim(ylim)
ax.set_title("b) 40 passengers, 8 exiting, 8 entering")
ax.grid()

# 60/12/12
ax = axs[1][0]
ax.boxplot(y12, positions=x, widths=[2, 2, 2, 2])
ax.set_ylabel("Enter/exit-time")

ax.set_xticks(
    x,
    [
        "Any door\nNo check",
        "Any door\nWith check",
        "Front door\nNo check",
        "Front door\nWith check",
    ],
)

ax.set_ylim(ylim)
ax.set_title("c) 60 passengers, 12 exiting, 12 entering")
ax.grid()

# 80/16/16
ax = axs[1][1]
ax.boxplot(y16, positions=x, widths=[2, 2, 2, 2])
ax.set_ylabel("Enter/exit-time")

ax.set_xticks(
    x,
    [
        "Any door\nNo check",
        "Any door\nWith check",
        "Front door\nNo check",
        "Front door\nWith check",
    ],
)

ax.set_ylim(ylim)
ax.set_title("d) 80 passengers, 16 exiting, 16 entering")
ax.grid()

fig.set_size_inches(15, 12)

# %%
# Any door no check
a_adnc = np.loadtxt("outputs/any_door-no_check_20_4.csv")
b_adnc = np.loadtxt("outputs/any_door-no_check_40_8.csv")
c_adnc = np.loadtxt("outputs/any_door-no_check_60_12.csv")
d_adnc = np.loadtxt("outputs/any_door-no_check_80_16.csv")

x_adnc = [3.7, 7.7, 11.7, 15.7]
y_adnc = [np.mean(a_adnc), np.mean(b_adnc), np.mean(c_adnc), np.mean(d_adnc)]
yerr_adnc = [np.std(a_adnc), np.std(b_adnc), np.std(c_adnc), np.std(d_adnc)]

# Any door with check
a_adwc = np.loadtxt("outputs/any_door-with_check_20_4.csv")
b_adwc = np.loadtxt("outputs/any_door-with_check_40_8.csv")
c_adwc = np.loadtxt("outputs/any_door-with_check_60_12.csv")
d_adwc = np.loadtxt("outputs/any_door-with_check_80_16.csv")

x_adwc = [3.9, 7.9, 11.9, 15.9]
y_adwc = [np.mean(a_adwc), np.mean(b_adwc), np.mean(c_adwc), np.mean(d_adwc)]
yerr_adwc = [np.std(a_adwc), np.std(b_adwc), np.std(c_adwc), np.std(d_adwc)]


# Front door no check
a_fdnc = np.loadtxt("outputs/front_door-no_check_20_4.csv")
b_fdnc = np.loadtxt("outputs/front_door-no_check_40_8.csv")
c_fdnc = np.loadtxt("outputs/front_door-no_check_60_12.csv")
d_fdnc = np.loadtxt("outputs/front_door-no_check_80_16.csv")

x_fdnc = [4.1, 8.1, 12.1, 16.1]
y_fdnc = [np.mean(a_fdnc), np.mean(b_fdnc), np.mean(c_fdnc), np.mean(d_fdnc)]
yerr_fdnc = [np.std(a_fdnc), np.std(b_fdnc), np.std(c_fdnc), np.std(d_fdnc)]


# Front door with check
a_fdwc = np.loadtxt("outputs/front_door-with_check_20_4.csv")
b_fdwc = np.loadtxt("outputs/front_door-with_check_40_8.csv")
c_fdwc = np.loadtxt("outputs/front_door-with_check_60_12.csv")
d_fdwc = np.loadtxt("outputs/front_door-with_check_80_16.csv")

x_fdwc = [4.3, 8.3, 12.3, 16.3]
y_fdwc = [np.mean(a_fdwc), np.mean(b_fdwc), np.mean(c_fdwc), np.mean(d_fdwc)]
yerr_fdwc = [np.std(a_fdwc), np.std(b_fdwc), np.std(c_fdwc), np.std(d_fdwc)]


plt.errorbar(x_adnc,y_adnc, yerr_adnc, fmt="o-", label="Any door, no ticket check")
plt.errorbar(x_adwc,y_adwc, yerr_adwc, fmt="o-", label="Any door, with ticket check")
plt.errorbar(x_fdnc,y_fdnc, yerr_fdnc, fmt="o-", label="Front door, no ticket check")
plt.errorbar(x_fdwc,y_fdwc, yerr_fdwc, fmt="o-", label="Front door, with ticket check")

plt.xlabel("# of entering/exiting passengers, slightly offset for readability")
plt.ylabel("Enter/exit-time")
plt.ylim([0, 35])
plt.title("Trends and errors for different rules")
plt.legend()
plt.xticks([4, 8, 12, 16])
plt.grid()
plt.show()
